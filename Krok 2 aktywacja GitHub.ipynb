# %% [markdown]
# # Krok 2:  GipHub

# %% [markdown]
# ### Wstawianie plików z ręki

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Usuwanie pliku z repozytorium

# %%
https://git-scm.com/docs/git-rm

# %% [markdown]
# ## Wgrywanie plików z terminala

# %% [markdown]
# ### 1. Geneowanie klucza SSH

# %% [markdown]
# ### Instalowanie GITa na Windows

# %% [markdown]
# https://gitforwindows.org/

# %% [markdown]
# https://stormit.pl/git-ssh/

# %% [markdown]
# #### Generujemy klucz SSH tylko tym w

# %%
C:\Users\wtm69\.ssh>ssh-keygen

# %% [markdown]
# C:\Users\wtm69\.ssh>ssh-keygen
#
#     i same ENTER, ENTER, ENTER, ENTER

# %% [markdown]
# Klucz zostaje umieszczony w katalogu .ssh można wyświetlić ---> są dwa lucze jeden pub (publiczny) drugi prywatny wklejamy do GITa prywatny

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Wstawianie klucza SSH do GITa

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Sprawdzamy połączenie

# %% [markdown]
# C:\Users\wtm69\.ssh>ssh -T git@github.com

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TWORZENIE REPOZYTORIUM

# %% [markdown]
# #####  ZAKŁADAM REPOZYTORIUM W GITHUB
# kopiuje adres

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# czyszczę ścieżkę

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# tworze klona

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# powstaje nowy katalg

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### przy pierwszym razie trzeba się jeszcze zameldować

# %% [markdown]
# C:\nowe>git config --global user.email "wtm695450085@gmail.com"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Wysyłam pliki na gita

# %% [markdown]
# ![image.png](attachment:image.png)
