# %% [markdown]
# ## Krok 1 Ściąganie plików z dysku google do Jupytera/Pythona

# %% [markdown]
# mam sobie jakiś plik

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# zdjęcie zabezpieczenia z pliku i skopiowanie adresu

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import gdown
## To jest adres pliku na google dysku uzyskany przez kopiuj adres

url='https://drive.google.com/file/d/11KvuNKqPfGdxJM05G7mPoSw9eXmerAb9/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]

output = 'C:/Users/wtm69/Downloads/airports.csv'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11KvuNKqPfGdxJM05G7mPoSw9eXmerAb9
# To: C:\Users\wtm69\Downloads\airports.csv
# 100%|██████████| 9.10M/9.10M [00:06<00:00, 1.40MB/s]
# 'C:/Users/wtm69/Downloads/airports.csv'

# %%
import pandas as pd

df = pd.read_csv('C:/Users/wtm69/Downloads/airports.csv')
df
# Out:
#            id    ident            type                                name  \
# 0        6523      00A        heliport                   Total Rf Heliport
# 1      323361     00AA   small_airport                Aero B Ranch Airport
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4        6526     00AR          closed  Newport Hospital & Clinic Heliport
# ...       ...      ...             ...                                 ...
# 61216  317861     ZYYK  medium_airport               Yingkou Lanqi Airport
# 61217   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 61218   46378  ZZ-0001        heliport                     Sealand Helipad
# 61219  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 61220  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
# ...

# %% [markdown]
# inny plik

# %% [markdown]
# https://drive.google.com/file/d/1YzMydmjHdYYqAqsAAKTyiGi1gn6yI3Hf/view?usp=sharing

# %%
import gdown
## To jest adres pliku na google dysku uzyskany przez kopiuj adres

url='https://drive.google.com/file/d/137Ka6eQftjLf9R7i2dK5DA7N-uZzB9hy/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]

output = 'C:/Users/wtm69/Downloads/aaqq11.png'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=137Ka6eQftjLf9R7i2dK5DA7N-uZzB9hy
# To: C:\Users\wtm69\Downloads\aaqq11.png
# 100%|██████████| 1.27M/1.27M [00:00<00:00, 1.39MB/s]
# 'C:/Users/wtm69/Downloads/aaqq11.png'

# %% [markdown]
# można znaleźć ten obrazek na dysku
